# %% [markdown]
# #Day 1 Pandas

# %%
import pandas as pd
dataFrame = pd.read_csv("C:\\Users\\pvalluru\\Desktop\\Python_practice\\Pandas\\dataset\\pokemon_data.csv")
dataFrame.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
excelDataFrame = pd.read_excel("C:\\Users\\pvalluru\\Desktop\\Python_practice\\Pandas\\dataset\\pokemon_data.xlsx")
excelDataFrame.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
textDataFrame = pd.read_csv('C:\\Users\\pvalluru\\Desktop\\Python_practice\\Pandas\\dataset\\pokemon_data.txt', delimiter = '\t')
textDataFrame.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
dataFrame.tail(3)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# Read Header of the CSV

# %%
type(dataFrame.columns)
dataFrame.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
columnList = list(dataFrame.columns)
columnList
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary']

# %% [markdown]
# select specifice columns

# %%
dataFrame[['Name', 'Attack']].head(5)
# Out:
#                     Name  Attack
# 0              Bulbasaur      49
# 1                Ivysaur      62
# 2               Venusaur      82
# 3  VenusaurMega Venusaur     100
# 4             Charmander      52

# %% [markdown]
# read each row

# %%
dataFrame.iloc[0:4] # iloc -> integer location
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
#iterrows
for index, row in dataFrame.iterrows():
    if index <= 5:
        print(index, row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon

# %% [markdown]
# #loc gets rows (or columns) with particular labels from the index
# #iloc gets rows (or columns) at particular positions in the index

# %%
dataFrame.loc[dataFrame['Attack'] >= 100][['Name', 'Type 1', 'Type 2']]
# Out:
#                           Name   Type 1  Type 2
# 3        VenusaurMega Venusaur    Grass  Poison
# 7    CharizardMega Charizard X     Fire  Dragon
# 8    CharizardMega Charizard Y     Fire  Flying
# 12     BlastoiseMega Blastoise    Water     NaN
# 19       BeedrillMega Beedrill      Bug  Poison
# ..                         ...      ...     ...
# 795                    Diancie     Rock   Fairy
# 796        DiancieMega Diancie     Rock   Fairy
# 797        HoopaHoopa Confined  Psychic   Ghost
# 798         HoopaHoopa Unbound  Psychic    Dark
# 799                  Volcanion     Fire   Water
#
# [210 rows x 3 columns]

# %%
dataFrame.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
dataFrame.sort_values(['Name', 'HP'], ascending=[0, 1]).head(10)
# Out:
#        #              Name    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 794  718  Zygarde50% Forme    Dragon    Ground  108     100      121       81
# 695  634          Zweilous      Dark    Dragon   72      85       70       65
# 46    41             Zubat    Poison    Flying   40      45       35       30
# 631  570             Zorua      Dark       NaN   40      65       40       80
# 632  571           Zoroark      Dark       NaN   60     105       60      120
# 286  263         Zigzagoon    Normal       NaN   38      30       41       30
# 707  644            Zekrom    Dragon  Electric  100     150      120      120
# 582  523         Zebstrika  Electric       NaN   75     100       63       80
# 157  145            Zapdos  Electric    Flying   90      90       85      125
# 367  335          Zangoose    Normal       NaN   73     115       60       60
#
#      Sp. Def  Speed  Generation  Legendary
# 794       95     95           6       True
# ...

# %% [markdown]
# Changing the Data

# %%
dataFrame['Total'] = dataFrame['HP'] + dataFrame['Attack'] + dataFrame['Defense'] + dataFrame['Sp. Atk'] + dataFrame['Sp. Def'] + dataFrame['Speed']
dataFrame.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
dataFrame.drop(columns = ['Total'], inplace = True)
dataFrame.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
dataFrame['Total'] = dataFrame.iloc[:,4:10].sum(axis = 1)
dataFrame.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
columnList = list(dataFrame.columns.values)

# %%
dataFrame = dataFrame[columnList[0:4] + [columnList[-1]] + columnList[4:12]]
dataFrame.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# Saving our Data

# %%
dataFrame.to_csv("C:\\Users\\pvalluru\\Desktop\\Python_practice\\Pandas\\dataset\\modified_pokemon_data.csv", index = False)

# %%
dataFrame.to_excel("C:\\Users\\pvalluru\\Desktop\\Python_practice\\Pandas\\dataset\\modified_pokemon_data.xlsx", index = False)

# %%
dataFrame.to_csv("C:\\Users\\pvalluru\\Desktop\\Python_practice\\Pandas\\dataset\\modified_pokemon_data.txt", index = False, sep = '\t')

# %%
modified_pok_csv = pd.read_csv('C:\\Users\\pvalluru\\Desktop\\Python_practice\\Pandas\\dataset\\modified_pokemon_data.csv')
modified_pok_csv.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
modified_pok_excel = pd.read_excel('C:\\Users\\pvalluru\\Desktop\\Python_practice\\Pandas\\dataset\\modified_pokemon_data.xlsx')
modified_pok_excel.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
modified_pok_txt = pd.read_csv('C:\\Users\\pvalluru\\Desktop\\Python_practice\\Pandas\\dataset\\modified_pokemon_data.txt', delimiter = '\t')
modified_pok_txt.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# Filtering Data in DataFrame

# %%
new_dataFrame = dataFrame.loc[(dataFrame['Type 1'] == 'Grass') & (dataFrame['Type 2'] == 'Poison') & (dataFrame['HP'] > 70)]
new_dataFrame.reset_index(drop = True, inplace = True)
new_dataFrame
# Out:
#      #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0    3               Venusaur  Grass  Poison    525   80      82       83
# 1    3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 2   45              Vileplume  Grass  Poison    490   75      80       85
# 3   71             Victreebel  Grass  Poison    490   80     105       65
# 4  591              Amoonguss  Grass  Poison    464  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      100      100     80           1      False
# 1      122      120     80           1      False
# 2      110       90     50           1      False
# 3      100       70     70           1      False
# 4       85       80     30           5      False

# %%
dataFrame.loc[dataFrame['Name'].str.contains('Mega')].head(10)
# Out:
#        #                       Name   Type 1   Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur    Grass   Poison    625   80     100
# 7      6  CharizardMega Charizard X     Fire   Dragon    634   78     130
# 8      6  CharizardMega Charizard Y     Fire   Flying    634   78     104
# 12     9    BlastoiseMega Blastoise    Water      NaN    630   79     103
# 19    15      BeedrillMega Beedrill      Bug   Poison    495   65     150
# 23    18        PidgeotMega Pidgeot   Normal   Flying    579   83      80
# 71    65      AlakazamMega Alakazam  Psychic      NaN    590   55      50
# 87    80        SlowbroMega Slowbro    Water  Psychic    590   95      75
# 102   94          GengarMega Gengar    Ghost   Poison    600   60      65
# 124  115  KangaskhanMega Kangaskhan   Normal      NaN    590  105     125
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 3        123      122      120     80           1      False
# ...

# %%
dataFrame.loc[~dataFrame['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318   45      49       49
# 1      2              Ivysaur    Grass  Poison    405   60      62       63
# 2      3             Venusaur    Grass  Poison    525   80      82       83
# 4      4           Charmander     Fire     NaN    309   39      52       43
# 5      5           Charmeleon     Fire     NaN    405   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re
dataFrame.loc[dataFrame['Type 1'].str.contains('grass|fire', flags = re.I ,regex = True)]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 4      4             Charmander   Fire     NaN    309   39      52       43
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 735  667                 Litleo   Fire  Normal    369   62      50       58
# 736  668                 Pyroar   Fire  Normal    507   86      68       72
# 740  672                 Skiddo  Grass     NaN    350   66      65       48
# 741  673                 Gogoat  Grass     NaN    531  123     100       62
# 799  721              Volcanion   Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
dataFrame.loc[dataFrame['Name'].str.contains('^Pi[a-z]*', flags=re.I, regex = True)]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying    251   40      45
# 21    17            Pidgeotto    Normal    Flying    349   63      60
# 22    18              Pidgeot    Normal    Flying    479   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 30    25              Pikachu  Electric       NaN    320   35      55
# 136  127               Pinsir       Bug       NaN    500   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying    600   65     155
# 186  172                Pichu  Electric       NaN    205   20      40
# 219  204               Pineco       Bug       NaN    290   50      65
# 239  221            Piloswine       Ice    Ground    450  100     100
# 438  393               Piplup     Water       NaN    314   53      51
# 558  499              Pignite      Fire  Fighting    418   90      93
# ...

# %% [markdown]
# Conditional Changes

# %%
dataFrame.loc[dataFrame['Type 1'] == 'Fire'].head(10)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 42  37                     Vulpix   Fire     NaN    299  38      41       40
# 43  38                  Ninetales   Fire     NaN    505  73      76       75
# 63  58                  Growlithe   Fire     NaN    350  55      70       45
# 64  59                   Arcanine   Fire     NaN    555  90     110       80
# 83  77                     Ponyta   Fire     NaN    410  50      85       55
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4        60       50     65           1      False
# ...

# %%
dataFrame.loc[dataFrame['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'
dataFrame
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
dataFrame.loc[dataFrame['Type 1'] == 'Fire', 'Legendary'] = True
dataFrame.loc[dataFrame['Type 1'] == 'Fire'].head(10)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 42  37                     Vulpix   Fire     NaN    299  38      41       40
# 43  38                  Ninetales   Fire     NaN    505  73      76       75
# 63  58                  Growlithe   Fire     NaN    350  55      70       45
# 64  59                   Arcanine   Fire     NaN    555  90     110       80
# 83  77                     Ponyta   Fire     NaN    410  50      85       55
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4        60       50     65           1       True
# ...

# %%
dataFrame.loc[dataFrame['Type 1'] == 'Fire', ['Legendary', 'Generation']] = ['False', 10]
dataFrame.loc[dataFrame['Type 1'] == 'Fire'].head(10)
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 4    4                 Charmander   Fire     NaN    309  39      52       43
# 5    5                 Charmeleon   Fire     NaN    405  58      64       58
# 6    6                  Charizard   Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 42  37                     Vulpix   Fire     NaN    299  38      41       40
# 43  38                  Ninetales   Fire     NaN    505  73      76       75
# 63  58                  Growlithe   Fire     NaN    350  55      70       45
# 64  59                   Arcanine   Fire     NaN    555  90     110       80
# 83  77                     Ponyta   Fire     NaN    410  50      85       55
#
#     Sp. Atk  Sp. Def  Speed  Generation Legendary
# 4        60       50     65          10     False
# ...

# %%
dataFrame = modified_pok_csv.copy()
dataFrame.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %% [markdown]
# Aggregate Statistics(Groupby)

# %%
dataFrame.groupby(['Type 1']).mean().sort_values('Defense', ascending = False)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Steel     442.851852  487.703704  65.222222   92.703704  126.370370
# Rock      392.727273  453.750000  65.363636   92.863636  100.795455
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Ice       423.541667  433.458333  72.000000   72.750000   71.416667
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Psychic   380.807018  475.947368  70.631579   71.456140   67.684211
# ...

# %%
dataFrame.groupby(['Type 1']).mean().sort_values('Attack', ascending = False)
# Out:
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Ground    356.281250  437.500000  73.781250   95.750000   84.843750
# Rock      392.727273  453.750000  65.363636   92.863636  100.795455
# Steel     442.851852  487.703704  65.222222   92.703704  126.370370
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# Poison    251.785714  399.142857  67.250000   74.678571   68.821429
# Water     303.089286  430.455357  72.062500   74.151786   72.946429
# Ghost     486.500000  439.562500  64.437500   73.781250   81.187500
# Normal    319.173469  401.683673  77.275510   73.469388   59.846939
# Grass     344.871429  421.142857  67.271429   73.214286   70.800000
# ...

# %%
dataFrame.groupby(['Type 1']).sum().sort_values('Attack', ascending = False)
# Out:
#               #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Water     33946  48211  8071    8305     8170     8379     7898   7388
# Normal    31279  39365  7573    7200     5865     5470     6245   7012
# Grass     24141  29480  4709    5125     4956     5425     4930   4335
# Bug       23080  26146  3925    4897     4880     3717     4471   4256
# Fire      17025  23820  3635    4408     3524     4627     3755   3871
# Rock      17280  19965  2876    4086     4435     2787     3321   2460
# Psychic   21706  27129  4026    4073     3858     5609     4918   4645
# Dragon    15180  17617  2666    3588     2764     3099     2843   2657
# Ground    11401  14000  2361    3064     2715     1807     2008   2045
# Electric  15994  19510  2631    3040     2917     3961     3243   3718
# Dark      14302  13818  2071    2740     2177     2314     2155   2361
# Fighting   9824  11244  1886    2613     1780     1434     1747   1784
# ...

# %%
dataFrame.groupby(['Type 1']).count().sort_values('Name', ascending = False)
# Out:
#             #  Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Water     112   112      53    112  112     112      112      112      112
# Normal     98    98      37     98   98      98       98       98       98
# Grass      70    70      37     70   70      70       70       70       70
# Bug        69    69      52     69   69      69       69       69       69
# Psychic    57    57      19     57   57      57       57       57       57
# Fire       52    52      24     52   52      52       52       52       52
# Electric   44    44      17     44   44      44       44       44       44
# Rock       44    44      35     44   44      44       44       44       44
# Ghost      32    32      22     32   32      32       32       32       32
# Ground     32    32      19     32   32      32       32       32       32
# Dragon     32    32      21     32   32      32       32       32       32
# ...

# %%
dataFrame['count'] = 1
dataFrame.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  count
# 0       65       65     45           1      False      1
# ...

# %%
dataFrame.groupby(['Type 1', 'Type 2']).count()['count'].head(20)
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#         Grass        6
#         Ground       2
#         Poison      12
#         Rock         3
#         Steel        7
#         Water        1
# Dark    Dragon       3
#         Fighting     2
#         Fire         3
#         Flying       5
#         Ghost        2
#         Ice          2
#         Psychic      2
#         Steel        2
# Dragon  Electric     1
# Name: count, dtype: int64

# %% [markdown]
# working with large dataset

# %% [markdown]
# we read chunks to read large amount of data

# %%
for chunkFrame in pd.read_csv('C:\\Users\\pvalluru\\Desktop\\Python_practice\\Pandas\\dataset\\modified_pokemon_data.csv', chunksize = 100):
    print("each Chunk Size Frame")
# Out:
# each Chunk Size Frame
# each Chunk Size Frame
# each Chunk Size Frame
# each Chunk Size Frame
# each Chunk Size Frame
# each Chunk Size Frame
# each Chunk Size Frame
# each Chunk Size Frame

# %%
outPutChunkFrame = pd.DataFrame(columns = dataFrame.columns)
outPutChunkFrameList = list(outPutChunkFrame.columns.values)
outPutChunkFrameList
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'Total',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'count']

# %%
for chunkFrame in pd.read_csv('C:\\Users\\pvalluru\\Desktop\\Python_practice\\Pandas\\dataset\\modified_pokemon_data.csv', chunksize=100):
    chunkFrame['count'] = 1
    resultFrame = chunkFrame.groupby(['Type 1']).count()
    outPutChunkFrame = pd.concat([outPutChunkFrame, resultFrame], sort = True)
outPutChunkFrame.head(20)
# Out:
#            # Attack Defense Generation  HP Legendary Name Sp. Atk Sp. Def  \
# Bug       11     11      11         11  11        11   11      11      11
# Electric   4      4       4          4   4         4    4       4       4
# Fairy      2      2       2          2   2         2    2       2       2
# Fighting   5      5       5          5   5         5    5       5       5
# Fire      11     11      11         11  11        11   11      11      11
# Ghost      1      1       1          1   1         1    1       1       1
# Grass     10     10      10         10  10        10   10      10      10
# Ground     4      4       4          4   4         4    4       4       4
# Normal    15     15      15         15  15        15   15      15      15
# Poison    12     12      12         12  12        12   12      12      12
# Psychic    4      4       4          4   4         4    4       4       4
# Rock       3      3       3          3   3         3    3       3       3
# ...

# %%
outPutChunkFrame.head(5)
# Out:
#            # Attack Defense Generation  HP Legendary Name Sp. Atk Sp. Def  \
# Bug       11     11      11         11  11        11   11      11      11
# Electric   4      4       4          4   4         4    4       4       4
# Fairy      2      2       2          2   2         2    2       2       2
# Fighting   5      5       5          5   5         5    5       5       5
# Fire      11     11      11         11  11        11   11      11      11
#
#          Speed Total Type 1 Type 2 count
# Bug         11    11    NaN      9   NaN
# Electric     4     4    NaN      2   NaN
# Fairy        2     2    NaN      0   NaN
# Fighting     5     5    NaN      0   NaN
# Fire        11    11    NaN      3   NaN
